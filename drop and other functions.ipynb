# %% [markdown]
# <a href="https://colab.research.google.com/github/Rushikesh419/pandas-library-rivision/blob/main/drop%20and%20other%20functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv('/content/drive/MyDrive/survey_results_public.csv')

# %%
data
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
data.shape
# Out:
# (88883, 85)

# %%
data.isnull().sum()
# Out:
# Respondent          0
# MainBranch        552
# Hobbyist            0
# OpenSourcer         0
# OpenSource       2041
#                 ...
# Sexuality       12736
# Ethnicity       12215
# Dependents       5824
# SurveyLength     1899
# SurveyEase       1802
# Length: 85, dtype: int64

# %%
data.value_counts
# Out:
# <bound method DataFrame.value_counts of        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# ...

# %%
country_grp=data.groupby(['Country'])
country_grp.get_group('United States')
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 3               4  I am a developer by profession       No
# 12             13  I am a developer by profession      Yes
# 21             22  I am a developer by profession      Yes
# 22             23  I am a developer by profession      Yes
# 25             26  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 88818       78292                             NaN       No
# 88840       82717                             NaN       No
# 88844       83397                             NaN      Yes
# 88859       85642                             NaN       No
# 88877       88282                             NaN      Yes
#
#                                              OpenSourcer  \
# 3                                                  Never
# 12     Less than once a month but more than once per ...
# 21                               Less than once per year
# ...

# %%
data.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
country_grp['SocialMedia'].value_counts().loc['India']
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
data.dtypes
# Out:
# Respondent       int64
# MainBranch      object
# Hobbyist        object
# OpenSourcer     object
# OpenSource      object
#                  ...
# Sexuality       object
# Ethnicity       object
# Dependents      object
# SurveyLength    object
# SurveyEase      object
# Length: 85, dtype: object

# %%
data['Age']=data['Age'].astype(float)

# %%
data['Age'].mean()
# Out:
# 30.336698649160457

# %%
data['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
data['YearsCode'].replace('Less than 1 year',0,inplace=True)

# %%
data['YearsCode'].replace('More than 50 years',51,inplace=True)

# %%
data['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 0, '30', '9', '26', '40', '19', '15', '20', '28',
#        '25', '1', '22', '11', '33', '50', '41', '18', '34', '24', '23',
#        '42', '27', '21', '36', '32', '39', '38', '31', '37', 51, '29',
#        '44', '45', '48', '46', '43', '47', '49'], dtype=object)

# %%
data['YearsCode']=data['YearsCode'].astype(float)

# %%
data['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
data['YearsCode'].median()
# Out:
# 9.0

# %%
a=data.groupby('Country')
a

# %%
for country,country_df in a:
  print(country)
  print(country_df)
# Out:
# Streaming output truncated to the last 5000 lines.
#                                               OpenSource  \
# 53     OSS is, on average, of LOWER quality than prop...
# 114    OSS is, on average, of HIGHER quality than pro...
# 220    The quality of OSS and closed source software ...
# 227    The quality of OSS and closed source software ...
# 232    OSS is, on average, of HIGHER quality than pro...
# ...                                                  ...
# 88249  The quality of OSS and closed source software ...
# 88331  OSS is, on average, of HIGHER quality than pro...
# 88678                                                NaN
# 88744  OSS is, on average, of HIGHER quality than pro...
# 88857  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment Country  \
# 53                                    Employed full-time  Sweden
# 114                                   Employed full-time  Sweden
# ...

# %%
df=pd.read_csv('/content/drive/MyDrive/employs')

# %%
b=df.groupby('Team')
b

# %%
for team in b:
  print(team)
# Out:
# ('Business Development',     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 9      Frances  Female    8/8/2002         6:51 AM  139852    7.524
# 33        Jean  Female  12/18/1993         9:07 AM  119082   16.180
# 36      Rachel  Female   2/16/2009         8:47 PM  142032   12.599
# 38   Stephanie  Female   9/13/1986         1:52 AM   36844    5.574
# 41   Christine     NaN   6/28/2015         1:08 AM   66582   11.308
# ..         ...     ...         ...             ...     ...      ...
# 959     Albert    Male   9/19/1992         2:35 AM   45094    5.850
# 960    Stephen    Male  10/29/1989        11:34 PM   93997   18.093
# 971    Patrick    Male  12/30/2002         2:01 AM   75423    5.368
# 973    Russell    Male   5/10/2013        11:08 PM  137359   11.105
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
#
#     Senior Management                  Team
# 9                True  Business Development
# ...

# %%
a.get_group('India')
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 7               8             I code primarily as a hobby      Yes
# 9              10          I am a developer by profession      Yes
# 14             15  I am a student who is learning to code      Yes
# 49             50          I am a developer by profession      Yes
# 64             65          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 88808       77339                                     NaN      Yes
# 88825       79795                                     NaN      Yes
# 88852       83862                                     NaN      Yes
# 88853       84299                                     NaN      Yes
# 88864       86012                                     NaN      Yes
#
#                                              OpenSourcer  \
# 7                                Less than once per year
# ...

# %%
a.max()
# Out:
# <ipython-input-26-f432eed13108>:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   a.max()
#                                       Respondent Hobbyist  \
# Country
# Afghanistan                                88731      Yes
# Albania                                    85878      Yes
# Algeria                                    88186      Yes
# Andorra                                    83115      Yes
# Angola                                     87783      Yes
# ...                                          ...      ...
# Venezuela, Bolivarian Republic of...       87213      Yes
# Viet Nam                                   88682      Yes
# Yemen                                      88559      Yes
# Zambia                                     73166      Yes
# Zimbabwe                                   84155      Yes
#
# ...

# %%
a.mean()
# Out:
#                                         Respondent  YearsCode     CompTotal  \
# Country
# Afghanistan                           47441.431818   7.317073  5.418654e+07
# Albania                               41695.546512   6.518072  1.707424e+05
# Algeria                               43010.126866   6.473684  7.544398e+04
# Andorra                               50079.857143  10.500000  7.650000e+04
# Angola                                50569.400000   2.250000  2.020000e+05
# ...                                            ...        ...           ...
# Venezuela, Bolivarian Republic of...  43461.170455   9.477273  1.174443e+05
# Viet Nam                              43895.337662   6.504386  2.613438e+07
# Yemen                                 45331.157895   5.789474  1.375000e+05
# Zambia                                42096.833333   4.916667  2.774375e+04
# Zimbabwe                              37455.410256   6.000000  7.841667e+03
#
# ...

# %%
a.describe()
# Out:
#                                      Respondent                              \
#                                           count          mean           std
# Country
# Afghanistan                                44.0  47441.431818  26547.217894
# Albania                                    86.0  41695.546512  24199.484198
# Algeria                                   134.0  43010.126866  25308.029814
# Andorra                                     7.0  50079.857143  33627.941940
# Angola                                      5.0  50569.400000  28639.499460
# ...                                         ...           ...           ...
# Venezuela, Bolivarian Republic of...       88.0  43461.170455  25866.546647
# Viet Nam                                  231.0  43895.337662  24367.137680
# Yemen                                      19.0  45331.157895  29720.785671
# Zambia                                     12.0  42096.833333  21487.596443
# ...

# %%
data.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
data.shape
# Out:
# (88883, 85)

# %%
data.drop(columns=['Respondent','MainBranch','EdLevel'],inplace=True)

# %%
data.shape
# Out:
# (88883, 82)
