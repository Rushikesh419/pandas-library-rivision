# %% [markdown]
# <a href="https://colab.research.google.com/github/Rushikesh419/pandas-library-rivision/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv('/content/drive/MyDrive/seasons.csv')
data
# Out:
#        Unnamed: 0        player_name team_abbreviation   age  player_height  \
# 0               0      Dennis Rodman               CHI  36.0         198.12
# 1               1  Dwayne Schintzius               LAC  28.0         215.90
# 2               2       Earl Cureton               TOR  39.0         205.74
# 3               3        Ed O'Bannon               DAL  24.0         203.20
# 4               4        Ed Pinckney               MIA  34.0         205.74
# ...           ...                ...               ...   ...            ...
# 12300       12300    Markieff Morris               MIA  32.0         205.74
# 12301       12301     Markelle Fultz               ORL  24.0         193.04
# 12302       12302       Marcus Smart               BOS  28.0         193.04
# 12303       12303     Marcus Garrett               MIA  23.0         195.58
# 12304       12304       Micah Potter               DET  24.0         208.28
#
# ...

# %%
# value count for multiplr column
for i in data.columns:
  x=data[i].value_counts()
  print(x)
# Out:
# 0        1
# 8076     1
# 8198     1
# 8199     1
# 8200     1
#         ..
# 4104     1
# 4105     1
# 4106     1
# 4107     1
# 12304    1
# Name: Unnamed: 0, Length: 12305, dtype: int64
# Vince Carter        22
# Dirk Nowitzki       21
# Kevin Garnett       20
# Jamal Crawford      20
# Kobe Bryant         20
#                     ..
# JaJuan Johnson       1
# Carldell Johnson     1
# Derrick Byars        1
# Eric Dawson          1
# Micah Potter         1
# Name: player_name, Length: 2463, dtype: int64
# CLE    433
# TOR    428
# MIA    426
# LAC    424
# DAL    422
# WAS    422
# ATL    421
# PHI    420
# HOU    418
# SAS    413
# DEN    412
# ORL    411
# LAL    411
# NYK    410
# IND    410
# MIL    409
# GSW    409
# POR    407
# BOS    407
# CHI    406
# DET    400
# MIN    399
# PHX    399
# SAC    398
# UTA    397
# MEM    352
# CHA    288
# NJN    257
# OKC    239
# SEA    182
# BKN    180
# NOP    159
# NOH    143
# CHH     89
# VAN     72
# NOK     32
# ...

# %%
data[['team_abbreviation','college','draft_year']].value_counts()
# Out:
# team_abbreviation  college        draft_year
# DAL                None           1998          23
# WAS                None           2005          20
# MIA                Florida        Undrafted     20
# DAL                None           Undrafted     20
# LAL                None           1996          20
#                                                 ..
#                    McNeese State  Undrafted      1
#                    Memphis        2006           1
#                    Miami (OH)     Undrafted      1
#                    Michigan       2018           1
# WAS                Xavier         Undrafted      1
# Length: 5847, dtype: int64

# %%
for column in data.columns:
  print(data[column].value_counts())
# Out:
# 0        1
# 8076     1
# 8198     1
# 8199     1
# 8200     1
#         ..
# 4104     1
# 4105     1
# 4106     1
# 4107     1
# 12304    1
# Name: Unnamed: 0, Length: 12305, dtype: int64
# Vince Carter        22
# Dirk Nowitzki       21
# Kevin Garnett       20
# Jamal Crawford      20
# Kobe Bryant         20
#                     ..
# JaJuan Johnson       1
# Carldell Johnson     1
# Derrick Byars        1
# Eric Dawson          1
# Micah Potter         1
# Name: player_name, Length: 2463, dtype: int64
# CLE    433
# TOR    428
# MIA    426
# LAC    424
# DAL    422
# WAS    422
# ATL    421
# PHI    420
# HOU    418
# SAS    413
# DEN    412
# ORL    411
# LAL    411
# NYK    410
# IND    410
# MIL    409
# GSW    409
# POR    407
# BOS    407
# CHI    406
# DET    400
# MIN    399
# PHX    399
# SAC    398
# UTA    397
# MEM    352
# CHA    288
# NJN    257
# OKC    239
# SEA    182
# BKN    180
# NOP    159
# NOH    143
# CHH     89
# VAN     72
# NOK     32
# ...

# %%
data['draft_year'].nunique()
# Out:
# 47

# %%
#rows selection
# iloc method
data.iloc[0:2]
# Out:
#    Unnamed: 0        player_name team_abbreviation   age  player_height  \
# 0           0      Dennis Rodman               CHI  36.0         198.12
# 1           1  Dwayne Schintzius               LAC  28.0         215.90
#
#    player_weight                      college country draft_year draft_round  \
# 0       99.79024  Southeastern Oklahoma State     USA       1986           2
# 1      117.93392                      Florida     USA       1990           1
#
#    ...  pts   reb  ast  net_rating  oreb_pct  dreb_pct  usg_pct  ts_pct  \
# 0  ...  5.7  16.1  3.1        16.1     0.186     0.323    0.100   0.479
# 1  ...  2.3   1.5  0.3        12.3     0.078     0.151    0.175   0.430
#
#    ast_pct   season
# 0    0.113  1996-97
# 1    0.048  1996-97
#
# [2 rows x 22 columns]

# %%
data.iloc[0:10:2]
# Out:
#    Unnamed: 0        player_name team_abbreviation   age  player_height  \
# 0           0      Dennis Rodman               CHI  36.0         198.12
# 2           2       Earl Cureton               TOR  39.0         205.74
# 4           4        Ed Pinckney               MIA  34.0         205.74
# 6           6        Eddie Jones               LAL  25.0         198.12
# 8           8  Eldridge Recasner               ATL  29.0         193.04
#
#    player_weight                      college country draft_year draft_round  \
# 0       99.79024  Southeastern Oklahoma State     USA       1986           2
# 2       95.25432                Detroit Mercy     USA       1979           3
# 4      108.86208                    Villanova     USA       1985           1
# 6       86.18248                       Temple     USA       1994           1
# 8       86.18248                   Washington     USA       1992   Undrafted
#
# ...

# %%
data.iloc[[1,2,3],3]
# Out:
# 1    28.0
# 2    39.0
# 3    24.0
# Name: age, dtype: float64

# %%
data.loc[[1,2],'team_abbreviation']
# Out:
# 1    LAC
# 2    TOR
# Name: team_abbreviation, dtype: object

# %%
data.loc[0:4,'team_abbreviation']
# Out:
# 0    CHI
# 1    LAC
# 2    TOR
# 3    DAL
# 4    MIA
# Name: team_abbreviation, dtype: object

# %%
fi=(data['team_abbreviation']=='CHI')
data[fi]
# Out:
#        Unnamed: 0      player_name team_abbreviation   age  player_height  \
# 0               0    Dennis Rodman               CHI  36.0         198.12
# 40             40  Dickey Simpkins               CHI  25.0         205.74
# 71             71     Jason Caffey               CHI  24.0         203.20
# 117           117  Bill Wennington               CHI  34.0         213.36
# 120           120       Bison Dele               CHI  28.0         210.82
# ...           ...              ...               ...   ...            ...
# 12230       12230       Lonzo Ball               CHI  24.0         198.12
# 12252       12252   Nikola Vucevic               CHI  31.0         208.28
# 12272       12272     Malcolm Hill               CHI  26.0         198.12
# 12290       12290      Matt Thomas               CHI  27.0         190.50
# 12299       12299  Marko Simonovic               CHI  22.0         210.82
#
#        player_weight                      college     country draft_year  \
# ...

# %%
# or 
data[data['team_abbreviation']=='CHI']
# Out:
#        Unnamed: 0      player_name team_abbreviation   age  player_height  \
# 0               0    Dennis Rodman               CHI  36.0         198.12
# 40             40  Dickey Simpkins               CHI  25.0         205.74
# 71             71     Jason Caffey               CHI  24.0         203.20
# 117           117  Bill Wennington               CHI  34.0         213.36
# 120           120       Bison Dele               CHI  28.0         210.82
# ...           ...              ...               ...   ...            ...
# 12230       12230       Lonzo Ball               CHI  24.0         198.12
# 12252       12252   Nikola Vucevic               CHI  31.0         208.28
# 12272       12272     Malcolm Hill               CHI  26.0         198.12
# 12290       12290      Matt Thomas               CHI  27.0         190.50
# 12299       12299  Marko Simonovic               CHI  22.0         210.82
#
#        player_weight                      college     country draft_year  \
# ...

# %%
data.loc[fi,'team_abbreviation']
# Out:
# 0        CHI
# 40       CHI
# 71       CHI
# 117      CHI
# 120      CHI
#         ...
# 12230    CHI
# 12252    CHI
# 12272    CHI
# 12290    CHI
# 12299    CHI
# Name: team_abbreviation, Length: 406, dtype: object

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'player_name', 'team_abbreviation', 'age',
#        'player_height', 'player_weight', 'college', 'country', 'draft_year',
#        'draft_round', 'draft_number', 'gp', 'pts', 'reb', 'ast', 'net_rating',
#        'oreb_pct', 'dreb_pct', 'usg_pct', 'ts_pct', 'ast_pct', 'season'],
#       dtype='object')

# %%
data.apply(len,axis=0)
# Out:
# Unnamed: 0           12305
# player_name          12305
# team_abbreviation    12305
# age                  12305
# player_height        12305
# player_weight        12305
# college              12305
# country              12305
# draft_year           12305
# draft_round          12305
# draft_number         12305
# gp                   12305
# pts                  12305
# reb                  12305
# ast                  12305
# net_rating           12305
# oreb_pct             12305
# dreb_pct             12305
# usg_pct              12305
# ts_pct               12305
# ast_pct              12305
# season               12305
# dtype: int64

# %%
data['BMI']=data['player_weight']/data['player_height']
data
# Out:
#        Unnamed: 0        player_name team_abbreviation   age  player_height  \
# 0               0      Dennis Rodman               CHI  36.0         198.12
# 1               1  Dwayne Schintzius               LAC  28.0         215.90
# 2               2       Earl Cureton               TOR  39.0         205.74
# 3               3        Ed O'Bannon               DAL  24.0         203.20
# 4               4        Ed Pinckney               MIA  34.0         205.74
# ...           ...                ...               ...   ...            ...
# 12300       12300    Markieff Morris               MIA  32.0         205.74
# 12301       12301     Markelle Fultz               ORL  24.0         193.04
# 12302       12302       Marcus Smart               BOS  28.0         193.04
# 12303       12303     Marcus Garrett               MIA  23.0         195.58
# 12304       12304       Micah Potter               DET  24.0         208.28
#
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'player_name', 'team_abbreviation', 'age',
#        'player_height', 'player_weight', 'college', 'country', 'draft_year',
#        'draft_round', 'draft_number', 'gp', 'pts', 'reb', 'ast', 'net_rating',
#        'oreb_pct', 'dreb_pct', 'usg_pct', 'ts_pct', 'ast_pct', 'season',
#        'BMI'],
#       dtype='object')

# %%
data.sort_values(by=['player_height','player_weight'])
# Out:
#        Unnamed: 0       player_name team_abbreviation   age  player_height  \
# 2090         2090     Muggsy Bogues               TOR  36.0         160.02
# 401           401     Muggsy Bogues               CHH  32.0         160.02
# 484           484     Muggsy Bogues               GSW  33.0         160.02
# 1125         1125     Muggsy Bogues               GSW  34.0         160.02
# 1727         1727     Muggsy Bogues               TOR  35.0         160.02
# ...           ...               ...               ...   ...            ...
# 6374         6374          Yao Ming               HOU  30.0         228.60
# 12101       12101        Tacko Fall               CLE  26.0         228.60
# 92             92  Gheorghe Muresan               WAS  26.0         231.14
# 1214         1214  Gheorghe Muresan               NJN  28.0         231.14
# 1407         1407  Gheorghe Muresan               NJN  29.0         231.14
#
# ...

# %%
data['player_weight'].nlargest()
# Out:
# 8288    163.293120
# 331     155.582056
# 3268    154.221280
# 2876    151.953320
# 1627    149.685360
# Name: player_weight, dtype: float64

# %%
data.at[8288,'player_name']
# Out:
# 'Sim Bhullar'

# %%
df=pd.read_csv('/content/drive/MyDrive/employs')
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df['Salary'].median()
# Out:
# 90428.0

# %%
df['Salary'].mode()
# Out:
# 0     86676
# 1     91462
# 2    121160
# 3    145988
# 4    147183
# Name: Salary, dtype: int64

# %%
df['Team'].value_counts()
# Out:
# Client Services         106
# Finance                 102
# Business Development    101
# Marketing                98
# Product                  95
# Sales                    94
# Engineering              92
# Human Resources          91
# Distribution             90
# Legal                    88
# Name: Team, dtype: int64

# %%
df1=data.groupby(['college'])

# %%
a=df1.get_group('Wake Forest')
a
# Out:
#        Unnamed: 0         player_name team_abbreviation   age  player_height  \
# 250           250  Randolph Childress               DET  24.0         187.96
# 273           273       Rodney Rogers               LAC  26.0         200.66
# 401           401       Muggsy Bogues               CHH  32.0         160.02
# 484           484       Muggsy Bogues               GSW  33.0         160.02
# 567           567          Tim Duncan               SAS  22.0         213.36
# ...           ...                 ...               ...   ...            ...
# 11778       11778        Jaylen Hoard               OKC  23.0         203.20
# 11795       11795        John Collins               ATL  24.0         205.74
# 11820       11820           Ish Smith               WAS  33.0         182.88
# 11832       11832       James Johnson               BKN  35.0         200.66
# 11967       11967          Chris Paul               PHX  37.0         182.88
#
# ...

# %%
a['draft_round'].value_counts()
# Out:
# 1            102
# Undrafted     20
# 2              9
# Name: draft_round, dtype: int64

# %%
a['country'].value_counts()
# Out:
# USA                  101
# US Virgin Islands     19
# Lithuania              8
# France                 3
# Name: country, dtype: int64

# %%
a['country'].value_counts().loc['France']
# Out:
# 3
